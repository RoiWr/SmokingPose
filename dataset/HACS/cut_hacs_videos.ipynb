# %% [markdown]
# # CUT HACS videos

# %%
violent_classes = ['Doing fencing','Sumo','Doing kickboxing','Doing karate','Hitting a pinata']
non_violent_classes = ['Beer pong','Ballet','Cheerleading','Beach soccer','Zumba','Cumbia']

# %%
# !python cut_HACS_videos.py --category 'Hitting a pinata'
# Out:
# No. 170: Video aOpV0yylM8g not found or exists. skip to next video
# No. 171: Video hbnmqg2FrgA not found or exists. skip to next video
# No. 172: Video fUcaLwyUfS4 not found or exists. skip to next video
# No. 173: Video 83c2V2nJDeI not found or exists. skip to next video
# No. 174: Video MN1e1vkPwtA not found or exists. skip to next video
# No. 175: Video OpeCXUKaFYM not found or exists. skip to next video
# No. 668: Video G-30uZ7VpGc not found or exists. skip to next video
# No. 669: Video DAkE2DgUNTM not found or exists. skip to next video
# No. 670: Video KPWhpInPd8M not found or exists. skip to next video
# No. 671: Video uFQpft1q3Zs not found or exists. skip to next video
# No. 672: Video XznO1ZAWho0 not found or exists. skip to next video
# No. 1214: Video Ksa3rmRq31E not found or exists. skip to next video
# No. 1215: Video RnH4mrNju2c not found or exists. skip to next video
# No. 1216: Video gqiUA5zKtkI not found or exists. skip to next video
# ...
